# %% [markdown]
# <a href="https://colab.research.google.com/github/0x11c11e/Data-Analysis/blob/master/Attack_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ucinlp/maestro-public.git
# Out:
# Cloning into 'maestro-public'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 74 (delta 33), reused 30 (delta 8), pack-reused 0
# Unpacking objects: 100% (74/74), done.

# %%
! pip install -r maestro-public/requirements.txt
# Out:
# ...
#   Using cached torch-1.11.0-cp37-cp37m-manylinux1_x86_64.whl (750.6 MB)
# ...
#   Using cached torchvision-0.12.0-cp37-cp37m-manylinux1_x86_64.whl (21.0 MB)
# ...

# %%
! python maestro-public/tasks/attack_homework/submission/attack.py

# %%
# %cd /content/maestro-public/tasks/attack_homework/
# Out:
# /content/maestro-public/tasks/attack_homework

# %%
! python Evaluator_attack_homework.py
# Out:
# Streaming output truncated to the last 5000 lines.
# None
# generation:  101
# None
# generation:  102
# None
# generation:  103
# None
# generation:  104
# None
# generation:  105
# None
# generation:  106
# None
# generation:  107
# None
# generation:  108
# None
# generation:  109
# None
# generation:  110
# None
# generation:  111
# None
# generation:  112
# None
# generation:  113
# None
# generation:  114
# None
# generation:  115
# None
# generation:  116
# None
# generation:  117
# None
# generation:  118
# None
# generation:  119
# None
# generation:  120
# None
# generation:  121
# None
# generation:  122
# None
# generation:  123
# None
# generation:  124
# None
# generation:  125
# None
# generation:  126
# None
# generation:  127
# None
# generation:  128
# None
# generation:  129
# None
# generation:  130
# None
# generation:  131
# None
# generation:  132
# None
# generation:  133
# None
# generation:  134
# None
# generation:  135
# None
# generation:  136
# None
# ...
